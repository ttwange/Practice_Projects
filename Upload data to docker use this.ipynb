# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\dataset\yellow_tripdata_2021-01.csv")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4056\3015608410.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\dataset\yellow_tripdata_2021-01.csv")

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
engine = create_engine('***://***:***@***:***/ny_tax')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" FLOAT(53),
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\dataset\yellow_tripdata_2021-01.csv", iterator=True, chunksize=100000)

# %%
df_iter

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1             1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2             1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3             1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4             2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ...         ...                  ...                   ...              ...
# 99995         1  2021-01-04 14:04:31   2021-01-04 14:08:52                3
# 99996         1  2021-01-04 14:18:46   2021-01-04 14:35:45                2
# 99997         1  2021-01-04 14:42:41   2021-01-04 14:59:22                2
# 99998         2  2021-01-04 14:39:02   2021-01-04 15:09:37                2
# 99999         2  2021-01-04 14:49:36   2021-01-04 14:54:44                5
#
# ...

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: total: 5.34 s
# Wall time: 13.3 s
# 1000

# %%
from time import time

# %%
while True: 
    t_start = time()

    df = next(df_iter)

    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    
    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk, took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk, took 12.466 second
# inserted another chunk, took 12.911 second
# inserted another chunk, took 13.033 second
# inserted another chunk, took 14.571 second
# inserted another chunk, took 14.938 second
# inserted another chunk, took 13.378 second
# inserted another chunk, took 13.504 second
# inserted another chunk, took 12.937 second
# inserted another chunk, took 13.229 second
# inserted another chunk, took 14.893 second
# inserted another chunk, took 12.595 second
# C:\Users\User\AppData\Local\Temp\ipykernel_4056\2113580993.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted another chunk, took 12.345 second
# inserted another chunk, took 8.033 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Input In [17], in <cell line: 2>()
#       1 while True:
# ...

# %%
query = """
SELECT * FROM yellow_taxi_data LIMIT 10
"""

pd.read_sql(query, con=engine)
# Out:
#    index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      0         1  2021-01-01 00:30:10   2021-01-01 00:36:12
# 1      1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2      2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3      3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4      4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
# 5      5         1  2021-01-01 00:16:29   2021-01-01 00:24:30
# 6      6         1  2021-01-01 00:00:28   2021-01-01 00:17:28
# 7      7         1  2021-01-01 00:12:29   2021-01-01 00:30:34
# 8      8         1  2021-01-01 00:39:16   2021-01-01 01:00:13
# 9      9         1  2021-01-01 00:26:12   2021-01-01 00:39:46
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                1           2.10           1                  N
# 1                1           0.20           1                  N
# 2                1          14.70           1                  N
# ...

# %%
query = """
SELECT max(tpep_pickup_datetime),min(tpep_pickup_datetime) FROM yellow_taxi_data LIMIT 10
"""

pd.read_sql(query, con=engine)
# Out:
#                   max                 min
# 0 2021-02-22 16:52:16 2008-12-31 23:05:14

# %%
query = """ 
SELECT * FROM yellow_taxi_data LIMIT 10
""" 
pd.read_sql(query, con=engine)
# Out:
#    index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      0         1  2021-01-01 00:30:10   2021-01-01 00:36:12
# 1      1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2      2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3      3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4      4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
# 5      5         1  2021-01-01 00:16:29   2021-01-01 00:24:30
# 6      6         1  2021-01-01 00:00:28   2021-01-01 00:17:28
# 7      7         1  2021-01-01 00:12:29   2021-01-01 00:30:34
# 8      8         1  2021-01-01 00:39:16   2021-01-01 01:00:13
# 9      9         1  2021-01-01 00:26:12   2021-01-01 00:39:46
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                1           2.10           1                  N
# 1                1           0.20           1                  N
# 2                1          14.70           1                  N
# ...
